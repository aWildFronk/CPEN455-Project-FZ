# %%
# !git pull
# !cd autograder
# !ls -a
# Out:
# Already up to date.
# .   autograder	examples  .gitignore  pyproject.toml   README.md  uv.lock
# ..  .env	.git	  model       .python-version  utils

# %%
# This config spends about 3 minutes to run on a Macmini with M4 Chip, 16GB RAM
# !cd autograder/
# !python examples/bayes_inverse.py \
    --method full_finetune \
    --max_seq_len 256 \
    --batch_size 8 \
    --num_iterations 80
# Out:
# Traceback (most recent call last):
#   File "/content/CPEN455-Project-FZ/examples/bayes_inverse.py", line 27, in <module>
#     from autograder.dataset import CPEN455_2025_W1_Dataset, ENRON_LABEL_INDEX_MAP, prepare_subset
# ModuleNotFoundError: No module named 'autograder'
